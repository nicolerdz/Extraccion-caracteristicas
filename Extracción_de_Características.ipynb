# %% [markdown]
# <a href="https://colab.research.google.com/github/nicolerdz/Extraccion-caracteristicas/blob/main/Extracci%C3%B3n_de_Caracter%C3%ADsticas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Extraccion de caracteristicas**
# Nicole Rodríguez A00831569

# %%
#Instalamos librería para análisis de variables categóricas
# %pip install funpymodeling
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached funpymodeling-0.1.7-py3-none-any.whl (6.4 kB)
# ...
#   Using cached seaborn-0.10.1-py3-none-any.whl (215 kB)
# ...
#   Using cached sklearn-0.0.post4.tar.gz (3.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#from funpymodeling.exploratory import freq_tbl

# %%
#Cargar archivo csv desde equipo
from google.colab import files
files.upload()

# %%
#Carga desde un archivo .xlsx sin indice
Micro_Retailer= pd.read_excel('microretailer_mit_lift_lab.xlsx')

# %%
#Verificamos información del DataFrame
Micro_Retailer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Columns: 106 entries, _record_id to 235_email
# dtypes: float64(23), int64(2), object(81)
# memory usage: 141.7+ KB

# %%
#Imprimo los primeros 5 registro del dataframe
Micro_Retailer.head()
# Out:
#                              _record_id             _title  \
# 0  dff2998e-af74-4de6-8efd-488aca24e67b  November 12, 2022
# 1  c596412f-4fc2-4983-acba-d9565859e42f  November 12, 2022
# 2  5bb632b3-41b5-4fb6-a817-b564e8b45a48  November 12, 2022
# 3  6774a0f6-bab4-4a58-bf94-95ad0b7cb438  November 12, 2022
# 4  6cc637fa-3d54-48c7-9499-6de13d0a26aa  November 12, 2022
#
#         _server_updated_at           _updated_by  \
# 0  2022-11-12 22:15:10 UTC  Salomon Abdala Perez
# 1  2022-11-12 22:15:09 UTC  Salomon Abdala Perez
# 2  2022-11-12 22:15:09 UTC  Salomon Abdala Perez
# 3  2022-11-12 22:15:09 UTC  Salomon Abdala Perez
# 4  2022-11-12 22:15:08 UTC  Salomon Abdala Perez
#
#                                        _geometry  _latitude  _longitude  \
# 0   SRID=4326;POINT(-98.233822273 19.0535362706)  19.053536  -98.233822
# 1  SRID=4326;POINT(-98.2341421351 19.0535610353)  19.053561  -98.234142
# 2    SRID=4326;POINT(-98.232299887 19.058654656)  19.058655  -98.232300
# ...

# %% [markdown]
# ## **DATOS NULOS**

# %%
#Corroboramos valores nulos
valores_nulos=Micro_Retailer.isnull().sum()
valores_nulos
# Out:
# _record_id                                0
# _title                                    0
# _server_updated_at                        0
# _updated_by                               0
# _geometry                                 0
#                                        ...
# 234_willingness_participate_workshop     73
# 318_shopkeeper_name                     123
# 319_shopkeepers_last_name               125
# 236_whatsapp                            129
# 235_email                               142
# Length: 106, dtype: int64

# %%
data1 =Micro_Retailer.fillna(method="bfill") 
data1
# Out:
#                                _record_id             _title  \
# 0    dff2998e-af74-4de6-8efd-488aca24e67b  November 12, 2022
# 1    c596412f-4fc2-4983-acba-d9565859e42f  November 12, 2022
# 2    5bb632b3-41b5-4fb6-a817-b564e8b45a48  November 12, 2022
# 3    6774a0f6-bab4-4a58-bf94-95ad0b7cb438  November 12, 2022
# 4    6cc637fa-3d54-48c7-9499-6de13d0a26aa  November 12, 2022
# ..                                    ...                ...
# 166  2413f06e-15cc-4a6f-8e83-5224c6824b12   November 3, 2022
# 167  962bf5a6-1eff-4874-a627-9cd8e3ca27b4   November 3, 2022
# 168  9ff658db-4dc5-48b6-aa0b-5c6668bb6720   November 3, 2022
# 169  e88aa9c1-dc8b-4180-99a1-2e0118ad905d   November 3, 2022
# 170  bf720ff0-3b7d-47ed-ba49-f5d4bfb7293c   November 3, 2022
#
#           _server_updated_at           _updated_by  \
# 0    2022-11-12 22:15:10 UTC  Salomon Abdala Perez
# 1    2022-11-12 22:15:09 UTC  Salomon Abdala Perez
# 2    2022-11-12 22:15:09 UTC  Salomon Abdala Perez
# ...

# %%
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# _record_id                              0
# _title                                  0
# _server_updated_at                      0
# _updated_by                             0
# _geometry                               0
#                                        ..
# 234_willingness_participate_workshop    5
# 318_shopkeeper_name                     5
# 319_shopkeepers_last_name               5
# 236_whatsapp                            5
# 235_email                               5
# Length: 106, dtype: int64

# %%
nulos = data1.columns[data1.isnull().any()]
data1[nulos] = data1[nulos].fillna('-')

# %%
valores_nulos=data1.isnull().sum().sum()
valores_nulos
# Out:
# 0

# %% [markdown]
# ## **VALORES ATIPICOS: PROCEDIMIENTO "CUANTILES"**

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y = data1.select_dtypes(include=[np.float, np.int])
x = data1.select_dtypes(include=[np.object])


percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido \n", Limite_Superior_iqr)
print("Limite inferior permitido \n", Limite_Inferior_iqr)
# Out:
# Limite superior permitido
#  _latitude                                            19.138774
# _longitude                                          -98.075320
# 97_number_of_customers_in_store                       5.000000
# 268_number_fridges                                    5.000000
# 104_how_many_shelves_does_the_micro_retailer_have    16.000000
# dtype: float64
# Limite inferior permitido
#  _latitude                                            18.950047
# _longitude                                          -98.355995
# 97_number_of_customers_in_store                      -3.000000
# 268_number_fridges                                   -3.000000
# 104_how_many_shelves_does_the_micro_retailer_have    -8.000000
# dtype: float64
# ...

# %%
outliers_iqr= y[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#      _latitude  _longitude  97_number_of_customers_in_store  \
# 0          NaN         NaN                              NaN
# 1          NaN         NaN                              NaN
# 2          NaN         NaN                              NaN
# 3          NaN         NaN                              NaN
# 4          NaN         NaN                              NaN
# ..         ...         ...                              ...
# 166        NaN         NaN                              NaN
# 167        NaN         NaN                              NaN
# 168        NaN         NaN                              NaN
# 169        NaN         NaN                              NaN
# 170        NaN         NaN                              NaN
#
#      268_number_fridges  104_how_many_shelves_does_the_micro_retailer_have
# 0                   NaN                                                NaN
# 1                   NaN                                                NaN
# ...

# %%
data3_iqr= y[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data3_iqr
# Out:
#      _latitude  _longitude  97_number_of_customers_in_store  \
# 0    19.053536  -98.233822                              2.0
# 1    19.053561  -98.234142                              0.0
# 2    19.058655  -98.232300                              0.0
# 3    19.059293  -98.233158                              0.0
# 4    19.059585  -98.233864                              0.0
# ..         ...         ...                              ...
# 166  19.043115  -98.194066                              1.0
# 167  19.042794  -98.193802                              1.0
# 168  19.042809  -98.193439                              3.0
# 169  19.042558  -98.193818                              0.0
# 170  19.042823  -98.193735                              1.0
#
#      268_number_fridges  104_how_many_shelves_does_the_micro_retailer_have
# 0                   0.0                                                4.0
# 1                   4.0                                                8.0
# ...

# %%
valores_nulos=data3_iqr.isnull().sum()
valores_nulos
# Out:
# _latitude                                             0
# _longitude                                            0
# 97_number_of_customers_in_store                       5
# 268_number_fridges                                   10
# 104_how_many_shelves_does_the_micro_retailer_have     9
# dtype: int64

# %%
data4_iqr=data3_iqr.copy()
data4_iqr=data4_iqr.fillna(round(data3_iqr.mean(),1))
data4_iqr
# Out:
#      _latitude  _longitude  97_number_of_customers_in_store  \
# 0    19.053536  -98.233822                              2.0
# 1    19.053561  -98.234142                              0.0
# 2    19.058655  -98.232300                              0.0
# 3    19.059293  -98.233158                              0.0
# 4    19.059585  -98.233864                              0.0
# ..         ...         ...                              ...
# 166  19.043115  -98.194066                              1.0
# 167  19.042794  -98.193802                              1.0
# 168  19.042809  -98.193439                              3.0
# 169  19.042558  -98.193818                              0.0
# 170  19.042823  -98.193735                              1.0
#
#      268_number_fridges  104_how_many_shelves_does_the_micro_retailer_have
# 0                   0.0                                                4.0
# 1                   4.0                                                8.0
# ...

# %%
data_clean = pd.concat([x, data4_iqr], axis=1)
data_clean
# Out:
#                                _record_id             _title  \
# 0    dff2998e-af74-4de6-8efd-488aca24e67b  November 12, 2022
# 1    c596412f-4fc2-4983-acba-d9565859e42f  November 12, 2022
# 2    5bb632b3-41b5-4fb6-a817-b564e8b45a48  November 12, 2022
# 3    6774a0f6-bab4-4a58-bf94-95ad0b7cb438  November 12, 2022
# 4    6cc637fa-3d54-48c7-9499-6de13d0a26aa  November 12, 2022
# ..                                    ...                ...
# 166  2413f06e-15cc-4a6f-8e83-5224c6824b12   November 3, 2022
# 167  962bf5a6-1eff-4874-a627-9cd8e3ca27b4   November 3, 2022
# 168  9ff658db-4dc5-48b6-aa0b-5c6668bb6720   November 3, 2022
# 169  e88aa9c1-dc8b-4180-99a1-2e0118ad905d   November 3, 2022
# 170  bf720ff0-3b7d-47ed-ba49-f5d4bfb7293c   November 3, 2022
#
#           _server_updated_at           _updated_by  \
# 0    2022-11-12 22:15:10 UTC  Salomon Abdala Perez
# 1    2022-11-12 22:15:09 UTC  Salomon Abdala Perez
# 2    2022-11-12 22:15:09 UTC  Salomon Abdala Perez
# ...

# %%
valores_nulos=data_clean.isnull().sum().sum()
valores_nulos
# Out:
# 0

# %% [markdown]
# ## **EXTRACCION CARACTERISTICAS**

# %% [markdown]
# 229_store_picture

# %%
#Obtengo un análisis univariado de las variables categóricas
freq_tbl(data_clean)

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(data_clean['229_store_picture'])
table1
# Out:
#   229_store_picture  frequency  percentage  cumulative_perc
# 0           1 Photo        166     0.97076          0.97076
# 1          2 Photos          5     0.02924          1.00000

# %%
#Ajusto el indice de mi dataframe
index1= table1.set_index('229_store_picture')
index1
# Out:
#                    frequency  percentage  cumulative_perc
# 229_store_picture
# 1 Photo                  166     0.97076          0.97076
# 2 Photos                   5     0.02924          1.00000

# %%
#Realizamos grafico de barras del dataframe filtrado
index1.plot(kind = 'bar', width=1, figsize=(10,4))
plt.xlabel('Cantidad fotos')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# 99_does_the_micro_retailer_exhibits_products_outside_

# %%
table2= freq_tbl(data_clean['99_does_the_micro_retailer_exhibits_products_outside_'])
index2= table2.set_index('99_does_the_micro_retailer_exhibits_products_outside_')
index2
# Out:
#                                                     frequency  percentage  \
# 99_does_the_micro_retailer_exhibits_products_ou...
# no                                                        120    0.701754
# yes                                                        51    0.298246
#
#                                                     cumulative_perc
# 99_does_the_micro_retailer_exhibits_products_ou...
# no                                                         0.701754
# yes                                                        1.000000

# %%
#Realizamos grafico de dispersión del dataframe filtrado
index2["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# 108_does_the_micro_retailer_has_a_barred_window_

# %%
table3= freq_tbl(data_clean['108_does_the_micro_retailer_has_a_barred_window_'])
index3= table3.set_index('108_does_the_micro_retailer_has_a_barred_window_')
index3
# Out:
#                                                   frequency  percentage  \
# 108_does_the_micro_retailer_has_a_barred_window_
# no                                                      124    0.725146
# yes                                                      47    0.274854
#
#                                                   cumulative_perc
# 108_does_the_micro_retailer_has_a_barred_window_
# no                                                       0.725146
# yes                                                      1.000000

# %%
index3["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# 102_does_the_micro_retailer_sells_fresh_products_

# %%
table4= freq_tbl(data_clean['102_does_the_micro_retailer_sells_fresh_products_'])
index4= table4.set_index('102_does_the_micro_retailer_sells_fresh_products_')
index4
# Out:
#                                                    frequency  percentage  \
# 102_does_the_micro_retailer_sells_fresh_products_
# no                                                       105    0.614035
# yes                                                       66    0.385965
#
#                                                    cumulative_perc
# 102_does_the_micro_retailer_sells_fresh_products_
# no                                                        0.614035
# yes                                                       1.000000

# %%
index4["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# 2_current_permanent_employees

# %%
table5= freq_tbl(data_clean['2_current_permanent_employees'])
index5= table5.set_index('2_current_permanent_employees')
index5
# Out:
#                                frequency  percentage  cumulative_perc
# 2_current_permanent_employees
# 1.0                                   46    0.269006         0.269006
# 0.0                                   46    0.269006         0.538012
# 2.0                                   41    0.239766         0.777778
# 4.0                                   16    0.093567         0.871345
# 3.0                                   12    0.070175         0.941520
# -                                      5    0.029240         0.970760
# 5.0                                    3    0.017544         0.988304
# 50.0                                   1    0.005848         0.994152
# 6.0                                    1    0.005848         1.000000

# %%
filtro5= index5[index5['frequency']>11]
filtro5
# Out:
#                                frequency  percentage  cumulative_perc
# 2_current_permanent_employees
# 1.0                                   46    0.269006         0.269006
# 0.0                                   46    0.269006         0.538012
# 2.0                                   41    0.239766         0.777778
# 4.0                                   16    0.093567         0.871345
# 3.0                                   12    0.070175         0.941520

# %%
filtro5.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %% [markdown]
# 6_change_employees_average_salary_last_year

# %%
table6= freq_tbl(data_clean['6_change_employees_average_salary_last_year'])
index6= table6.set_index('6_change_employees_average_salary_last_year')
index6
# Out:
#                                              frequency  percentage  \
# 6_change_employees_average_salary_last_year
# No cambió                                           97    0.567251
# Aumentó 15%                                         23    0.134503
# Aumentó 50% o más                                   12    0.070175
# No hay empleándosela                                10    0.058480
# Disminuyó 15%                                        8    0.046784
# -                                                    8    0.046784
# Disminuyó 25%                                        4    0.023392
# Aumentó 25%                                          4    0.023392
# 0                                                    2    0.011696
# Dependiente                                          1    0.005848
# Disminuyó 50% o más                                  1    0.005848
# 40                                                   1    0.005848
#
# ...

# %%
filtro6= index6[index6['frequency']>10]
filtro6
# Out:
#                                              frequency  percentage  \
# 6_change_employees_average_salary_last_year
# No cambió                                           97    0.567251
# Aumentó 15%                                         23    0.134503
# Aumentó 50% o más                                   12    0.070175
#
#                                              cumulative_perc
# 6_change_employees_average_salary_last_year
# No cambió                                           0.567251
# Aumentó 15%                                         0.701754
# Aumentó 50% o más                                   0.771930

# %%
filtro6.plot(kind='area', figsize=(10,4),alpha = 0.5)
# Out:
# <Axes: xlabel='6_change_employees_average_salary_last_year'>

# %% [markdown]
# 49_inventory_records

# %%
table7= freq_tbl(data_clean['49_inventory_records'])
index7= table7.set_index('49_inventory_records')
index7
# Out:
#                                                    frequency  percentage  \
# 49_inventory_records
# En papel                                                  60    0.350877
# En Excel                                                  31    0.181287
# Software especializado + computadora                      29    0.169591
# No lo hago                                                24    0.140351
# En Excel,En papel                                         17    0.099415
# -                                                          5    0.029240
# Aplicación móvil (i.e. App) + smartphone                   2    0.011696
# Mentalmente                                                1    0.005848
# En papel,Mental                                            1    0.005848
# Aplicación móvil (i.e. App) + smartphone,En Excel          1    0.005848
#
#                                                    cumulative_perc
# 49_inventory_records
# ...

# %%
filtro7= index7[index7['frequency']>10]
filtro7
# Out:
#                                       frequency  percentage  cumulative_perc
# 49_inventory_records
# En papel                                     60    0.350877         0.350877
# En Excel                                     31    0.181287         0.532164
# Software especializado + computadora         29    0.169591         0.701754
# No lo hago                                   24    0.140351         0.842105
# En Excel,En papel                            17    0.099415         0.941520

# %%
filtro7.plot(kind='area', figsize=(10,4),alpha = 0.5)
# Out:
# <Axes: xlabel='49_inventory_records'>

# %% [markdown]
# 103_number_own_fridges

# %%
table8= freq_tbl(data_clean['103_number_own_fridges'])
index8= table8.set_index('103_number_own_fridges')
index8
# Out:
#                         frequency  percentage  cumulative_perc
# 103_number_own_fridges
# 0.0                            63    0.368421         0.368421
# 1.0                            44    0.257310         0.625731
# 2.0                            36    0.210526         0.836257
# -                               9    0.052632         0.888889
# 5.0                             6    0.035088         0.923977
# 20.0                            5    0.029240         0.953216
# 3.0                             4    0.023392         0.976608
# 7.0                             4    0.023392         1.000000

# %%
filtro8= index8[index8['frequency']>10]
filtro8
# Out:
#                         frequency  percentage  cumulative_perc
# 103_number_own_fridges
# 0.0                            63    0.368421         0.368421
# 1.0                            44    0.257310         0.625731
# 2.0                            36    0.210526         0.836257

# %%
#Realizamos grafico de barras del dataframe filtrado
filtro8.plot(kind = 'bar', width=1, figsize=(10,4))
plt.xlabel('Cantidad refrigeradores')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# 145_number_direct_competitors

# %%
table9= freq_tbl(data_clean['145_number_direct_competitors'])
index9= table9.set_index('145_number_direct_competitors')
index9
# Out:
#                                frequency  percentage  cumulative_perc
# 145_number_direct_competitors
# 3.0                                   37    0.216374         0.216374
# 2.0                                   31    0.181287         0.397661
# 1.0                                   22    0.128655         0.526316
# 4.0                                   15    0.087719         0.614035
# 10.0                                  15    0.087719         0.701754
# 0.0                                   14    0.081871         0.783626
# 5.0                                   11    0.064327         0.847953
# 7.0                                    7    0.040936         0.888889
# 6.0                                    6    0.035088         0.923977
# -                                      5    0.029240         0.953216
# 8.0                                    3    0.017544         0.970760
# 15.0                                   3    0.017544         0.988304
# ...

# %%
filtro9= index9[index9['frequency']>10]
filtro9
# Out:
#                                frequency  percentage  cumulative_perc
# 145_number_direct_competitors
# 3.0                                   37    0.216374         0.216374
# 2.0                                   31    0.181287         0.397661
# 1.0                                   22    0.128655         0.526316
# 4.0                                   15    0.087719         0.614035
# 10.0                                  15    0.087719         0.701754
# 0.0                                   14    0.081871         0.783626
# 5.0                                   11    0.064327         0.847953

# %%
#Realizamos grafico de barras del dataframe filtrado
filtro9.plot(kind = 'bar', width=1, figsize=(10,4))
plt.xlabel('Cantidad competidores directos')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# 186_internet_connection

# %%
table10= freq_tbl(data_clean['186_internet_connection'])
index10= table10.set_index('186_internet_connection')
index10
# Out:
#                          frequency  percentage  cumulative_perc
# 186_internet_connection
# yes                            118    0.690058         0.690058
# no                              48    0.280702         0.970760
# -                                5    0.029240         1.000000

# %%
filtro10= index10[index10['frequency']>10]
filtro10
# Out:
#                          frequency  percentage  cumulative_perc
# 186_internet_connection
# yes                            118    0.690058         0.690058
# no                              48    0.280702         0.970760

# %%
filtro10["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# 28_prefered_payment_method

# %%
table11= freq_tbl(data_clean['28_prefered_payment_method'])
index11= table11.set_index('28_prefered_payment_method')
index11
# Out:
#                                frequency  percentage  cumulative_perc
# 28_prefered_payment_method
# Efectivo                              70    0.409357         0.409357
# Tarjeta de débito y/o crédito         59    0.345029         0.754386
# -                                     42    0.245614         1.000000

# %%
index11["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# 269_cash_discount

# %%
table12= freq_tbl(data_clean['269_cash_discount'])
index12= table12.set_index('269_cash_discount')
index12
# Out:
#                    frequency  percentage  cumulative_perc
# 269_cash_discount
# -                        117    0.684211         0.684211
# 2-5%                      49    0.286550         0.970760
# 6-10%                      5    0.029240         1.000000

# %%
index12.plot(kind='area', figsize=(10,4),alpha = 0.5)
# Out:
# <Axes: xlabel='269_cash_discount'>

# %% [markdown]
# 33_credit_to_customers

# %%
table13= freq_tbl(data_clean['33_credit_to_customers'])
index13= table13.set_index('33_credit_to_customers')
index13
# Out:
#                         frequency  percentage  cumulative_perc
# 33_credit_to_customers
# no                            130    0.760234         0.760234
# yes                            36    0.210526         0.970760
# -                               5    0.029240         1.000000

# %%
filtro13= index13[index13['frequency']>10]
filtro13
# Out:
#                         frequency  percentage  cumulative_perc
# 33_credit_to_customers
# no                            130    0.760234         0.760234
# yes                            36    0.210526         0.970760

# %%
filtro13["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# 227_agreement_ecommerce_platforms

# %%
table14= freq_tbl(data_clean['227_agreement_ecommerce_platforms'])
index14= table14.set_index('227_agreement_ecommerce_platforms')
index14
# Out:
#                                    frequency  percentage  cumulative_perc
# 227_agreement_ecommerce_platforms
# no                                       149    0.871345         0.871345
# yes                                       17    0.099415         0.970760
# -                                          5    0.029240         1.000000

# %%
filtro14= index14[index14['frequency']>10]
filtro14
# Out:
#                                    frequency  percentage  cumulative_perc
# 227_agreement_ecommerce_platforms
# no                                       149    0.871345         0.871345
# yes                                       17    0.099415         0.970760

# %%
#Realizamos grafico de barras del dataframe filtrado
filtro14.plot(kind = 'bar', width=1, figsize=(10,4))
plt.xlabel('E-commerce platforms')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# 317_home_deliveries

# %%
table15= freq_tbl(data_clean['317_home_deliveries'])
index15= table15.set_index('317_home_deliveries')
index15
# Out:
#                      frequency  percentage  cumulative_perc
# 317_home_deliveries
# 7.0                         47    0.274854         0.274854
# 2.0                         37    0.216374         0.491228
# 8.0                         19    0.111111         0.602339
# -                           18    0.105263         0.707602
# 40.0                        17    0.099415         0.807018
# 100.0                       10    0.058480         0.865497
# 10.0                         9    0.052632         0.918129
# 0.0                          5    0.029240         0.947368
# 21.0                         5    0.029240         0.976608
# 1.0                          3    0.017544         0.994152
# 28.0                         1    0.005848         1.000000

# %%
filtro15= index15[index15['frequency']>10]
filtro15
# Out:
#                      frequency  percentage  cumulative_perc
# 317_home_deliveries
# 7.0                         47    0.274854         0.274854
# 2.0                         37    0.216374         0.491228
# 8.0                         19    0.111111         0.602339
# -                           18    0.105263         0.707602
# 40.0                        17    0.099415         0.807018

# %%
filtro15.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %% [markdown]
# 312_payment_of_utilities

# %%
table16= freq_tbl(data_clean['312_payment_of_utilities'])
index16= table16.set_index('312_payment_of_utilities')
index16
# Out:
#                                 frequency  percentage  cumulative_perc
# 312_payment_of_utilities
# Totalmente en desacuerdo              104    0.608187         0.608187
# Algo de acuerdo                        30    0.175439         0.783626
# Totalmente de acuerdo                  20    0.116959         0.900585
# Ni de acuerdo ni en desacuerdo          7    0.040936         0.941520
# Algo en desacuerdo                      5    0.029240         0.970760
# -                                       5    0.029240         1.000000

# %%
filtro16= index16[index16['frequency']>10]
filtro16
# Out:
#                           frequency  percentage  cumulative_perc
# 312_payment_of_utilities
# Totalmente en desacuerdo        104    0.608187         0.608187
# Algo de acuerdo                  30    0.175439         0.783626
# Totalmente de acuerdo            20    0.116959         0.900585

# %%
filtro16.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %% [markdown]
# 53_special_conditions_suppliers

# %%
table17= freq_tbl(data_clean['53_special_conditions_suppliers'])
index17= table17.set_index('53_special_conditions_suppliers')
index17
# Out:
#                                                     frequency  percentage  \
# 53_special_conditions_suppliers
# Crédito                                                    49    0.286550
# Ninguno                                                    33    0.192982
# Descuento por compras anticipadas                          26    0.152047
# Promociones                                                12    0.070175
# No                                                          9    0.052632
# Consignación,Crédito,Descuento por compras anti...          8    0.046784
# Crédito,Descuento por compras anticipadas                   8    0.046784
# -                                                           5    0.029240
# Consignación                                                3    0.017544
# Recompra                                                    3    0.017544
# ninguno                                                     3    0.017544
# ...

# %%
filtro17= index17[index17['frequency']>8]
filtro17
# Out:
#                                    frequency  percentage  cumulative_perc
# 53_special_conditions_suppliers
# Crédito                                   49    0.286550         0.286550
# Ninguno                                   33    0.192982         0.479532
# Descuento por compras anticipadas         26    0.152047         0.631579
# Promociones                               12    0.070175         0.701754
# No                                         9    0.052632         0.754386

# %%
filtro17.plot(kind='area', figsize=(10,4),alpha = 0.5)
# Out:
# <Axes: xlabel='53_special_conditions_suppliers'>

# %% [markdown]
# 277_payment_method_suppliers

# %%
table18= freq_tbl(data_clean['277_payment_method_suppliers'])
index18= table18.set_index('277_payment_method_suppliers')
index18
# Out:
#                                                     frequency  percentage  \
# 277_payment_method_suppliers
# Efectivo                                                  108    0.631579
# Tarjeta de débito y/o crédito                              19    0.111111
# Transferencia interbancaria                                13    0.076023
# Efectivo,Tarjeta de débito y/o crédito                     13    0.076023
# Efectivo,Transferencia interbancaria                       10    0.058480
# -                                                           5    0.029240
# Efectivo,Tarjeta de débito y/o crédito,Transfer...          3    0.017544
#
#                                                     cumulative_perc
# 277_payment_method_suppliers
# Efectivo                                                   0.631579
# Tarjeta de débito y/o crédito                              0.742690
# Transferencia interbancaria                                0.818713
# ...

# %%
filtro18= index18[index18['frequency']>10]
filtro18
# Out:
#                                         frequency  percentage  cumulative_perc
# 277_payment_method_suppliers
# Efectivo                                      108    0.631579         0.631579
# Tarjeta de débito y/o crédito                  19    0.111111         0.742690
# Transferencia interbancaria                    13    0.076023         0.818713
# Efectivo,Tarjeta de débito y/o crédito         13    0.076023         0.894737

# %%
filtro18["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# 279_changes_procurement_pandemic

# %%
table19= freq_tbl(data_clean['279_changes_procurement_pandemic'])
index19= table19.set_index('279_changes_procurement_pandemic')
index19
# Out:
#                                                     frequency  percentage  \
# 279_changes_procurement_pandemic
# Disminuir la cantidad del pedido                           51    0.298246
# Disminución de la variedad de productos,Disminu...         26    0.152047
# Disminuir la frecuencia de pedidos                         25    0.146199
# Disminuir la cantidad del pedido,Disminuir la f...         19    0.111111
# Ninguna de las anteriores                                  18    0.105263
# Aumentar la cantidad del pedido                            16    0.093567
# Aumentar la variedad de productos.,Disminuir la...          6    0.035088
# -                                                           5    0.029240
# Aumentar la variedad de productos.                          3    0.017544
# Aumentar la cantidad del pedido,Disminución de ...          2    0.011696
#
#                                                     cumulative_perc
# 279_changes_procurement_pandemic
# ...

# %%
filtro19= index19[index19['frequency']>18]
filtro19
# Out:
#                                                     frequency  percentage  \
# 279_changes_procurement_pandemic
# Disminuir la cantidad del pedido                           51    0.298246
# Disminución de la variedad de productos,Disminu...         26    0.152047
# Disminuir la frecuencia de pedidos                         25    0.146199
# Disminuir la cantidad del pedido,Disminuir la f...         19    0.111111
#
#                                                     cumulative_perc
# 279_changes_procurement_pandemic
# Disminuir la cantidad del pedido                           0.298246
# Disminución de la variedad de productos,Disminu...         0.450292
# Disminuir la frecuencia de pedidos                         0.596491
# Disminuir la cantidad del pedido,Disminuir la f...         0.707602

# %%
#Realizamos grafico de barras del dataframe filtrado
filtro19.plot(kind = 'bar', width=1, figsize=(10,4))
plt.xlabel('Cambios pandemia')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# 157_frequency_organize_shelves

# %%
table20= freq_tbl(data_clean['157_frequency_organize_shelves'])
index20= table20.set_index('157_frequency_organize_shelves')
index20
# Out:
#                                 frequency  percentage  cumulative_perc
# 157_frequency_organize_shelves
# Semanalmente                           73    0.426901         0.426901
# Diariamente                            46    0.269006         0.695906
# Mensualmente                           17    0.099415         0.795322
# Nunca                                  16    0.093567         0.888889
# Quincenalmente                         10    0.058480         0.947368
# -                                       5    0.029240         0.976608
# Anualmente                              2    0.011696         0.988304
# Semestralmente                          1    0.005848         0.994152
# No se tiene                             1    0.005848         1.000000

# %%
filtro20= index20[index20['frequency']>9]
filtro20
# Out:
#                                 frequency  percentage  cumulative_perc
# 157_frequency_organize_shelves
# Semanalmente                           73    0.426901         0.426901
# Diariamente                            46    0.269006         0.695906
# Mensualmente                           17    0.099415         0.795322
# Nunca                                  16    0.093567         0.888889
# Quincenalmente                         10    0.058480         0.947368

# %%
#Realizamos grafico de barras del dataframe filtrado
filtro20.plot(kind = 'bar', width=1, figsize=(10,4))
plt.xlabel('Frecuencia de Organizacion Estantes')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
